# %%
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
df = pd.read_csv("./data/944.csv")
df
# Out:
#        Estación                         Título    latitud  longitud  \
# 0             1  Estación Avenida Constitución  43.529806 -5.673428
# 1             1  Estación Avenida Constitución  43.529806 -5.673428
# 2             1  Estación Avenida Constitución  43.529806 -5.673428
# 3             1  Estación Avenida Constitución  43.529806 -5.673428
# 4             1  Estación Avenida Constitución  43.529806 -5.673428
# ...         ...                            ...        ...       ...
# 43795         4      Estación Avenida Castilla  43.537940 -5.645951
# 43796         4      Estación Avenida Castilla  43.537940 -5.645951
# 43797         4      Estación Avenida Castilla  43.537940 -5.645951
# 43798         4      Estación Avenida Castilla  43.537940 -5.645951
# 43799         4      Estación Avenida Castilla  43.537940 -5.645951
#
#             Fecha  Periodo  SO2    NO   NO2    CO  ...    vv   TMP    HR  \
# 0      2022-12-31       24  2.0   1.0  11.0   NaN  ...  1.59  14.1  75.0
# ...

# %%
df1 = df.drop(["dd","vv","TMP","HR","PRB", "RS", "LL","BEN","TOL","MXIL"], axis= 1)
df1
# Out:
#        Estación                         Título    latitud  longitud  \
# 0             1  Estación Avenida Constitución  43.529806 -5.673428
# 1             1  Estación Avenida Constitución  43.529806 -5.673428
# 2             1  Estación Avenida Constitución  43.529806 -5.673428
# 3             1  Estación Avenida Constitución  43.529806 -5.673428
# 4             1  Estación Avenida Constitución  43.529806 -5.673428
# ...         ...                            ...        ...       ...
# 43795         4      Estación Avenida Castilla  43.537940 -5.645951
# 43796         4      Estación Avenida Castilla  43.537940 -5.645951
# 43797         4      Estación Avenida Castilla  43.537940 -5.645951
# 43798         4      Estación Avenida Castilla  43.537940 -5.645951
# 43799         4      Estación Avenida Castilla  43.537940 -5.645951
#
#             Fecha  Periodo  SO2    NO   NO2    CO  PM10    O3  PM25
# 0      2022-12-31       24  2.0   1.0  11.0   NaN  29.0  54.0  11.0
# ...

# %%
dfestacion1 = df1[df1["Estación"] == 1]
dfestacion1
# Out:
#       Estación                         Título    latitud  longitud  \
# 0            1  Estación Avenida Constitución  43.529806 -5.673428
# 1            1  Estación Avenida Constitución  43.529806 -5.673428
# 2            1  Estación Avenida Constitución  43.529806 -5.673428
# 3            1  Estación Avenida Constitución  43.529806 -5.673428
# 4            1  Estación Avenida Constitución  43.529806 -5.673428
# ...        ...                            ...        ...       ...
# 8755         1  Estación Avenida Constitución  43.529806 -5.673428
# 8756         1  Estación Avenida Constitución  43.529806 -5.673428
# 8757         1  Estación Avenida Constitución  43.529806 -5.673428
# 8758         1  Estación Avenida Constitución  43.529806 -5.673428
# 8759         1  Estación Avenida Constitución  43.529806 -5.673428
#
#            Fecha  Periodo   SO2    NO   NO2  CO  PM10    O3  PM25
# 0     2022-12-31       24   2.0   1.0  11.0 NaN  29.0  54.0  11.0
# ...

# %%
media_so2 = dfestacion1["SO2"].mean()
print("Media del Dióxido de Azufre de la estacion 1:", round(media_so2, 2))

media_no = dfestacion1["NO"].mean()
print("Media del Óxido Nítrico de la estacion 1:", round(media_no, 2))

media_no2 = dfestacion1["NO2"].mean()
print("Media del Dióxido de Nitrógeno de la estacion 1:", round(media_no2, 2))

media_co = dfestacion1["CO"].mean()
print("Media del Monóxido de carbono de la estacion 1:", round(media_co, 2))

media_pm10 = dfestacion1["PM10"].mean()
print("Media de partículas sólidas en el aire de hasta 10 micras de la estacion 1:", round(media_pm10, 2))

media_o3 = dfestacion1["O3"].mean()
print("Media del Ozono de la estacion 1:", round(media_o3, 2))

media_pm25 = dfestacion1["PM25"].mean()
print("Media de partículas sólidas en el aire de hasta 2,5 micras de la estacion 1:", round(media_pm25, 2))
# Out:
# Media del Dióxido de Azufre de la estacion 1: 2.3
# Media del Óxido Nïtrico de la estacion 1: 9.88
# Media del Dióxido de Nitrógeno de la estacion 1: 21.0
# Media del Monóxido de carbono de la estacion 1: nan
# Media de partículas sólidas en el aire de hasta 10 micras de la estacion 1: 30.86
# Media del Ozono de la estacion 1: 51.8
# Media de partículas sólidas en el aire de hasta 2,5 micras de la estacion 1: 12.34

# %%
moda_so2 = dfestacion1["SO2"].mode()
print("Moda del Dióxido de Azufre de la estacion 1:", round(moda_so2, 2))

moda_no = dfestacion1["NO"].mode()
print("Moda del Óxido Nítrico de la estacion 1:", round(moda_no, 2))

moda_no2 = dfestacion1["NO2"].mode()
print("Moda del Dióxido de Nitrógeno de la estacion 1:", round(moda_no2, 2))

moda_co = dfestacion1["CO"].mode()
print("Moda del Monóxido de carbono de la estacion 1:", round(moda_co, 2))

moda_pm10 = dfestacion1["PM10"].mode()
print("Moda de partículas sólidas en el aire de hasta 10 micras de la estacion 1:", round(moda_pm10, 2))

moda_o3 = dfestacion1["O3"].mode()
print("Moda del Ozono de la estacion 1:", round(moda_o3, 2))

moda_pm25 = dfestacion1["PM25"].mode()
print("Moda de partículas sólidas en el aire de hasta 2,5 micras de la estacion 1:", round(moda_pm25, 2))
# Out:
# Moda del Dióxido de Azufre de la estacion 1: 0    1.0
# Name: SO2, dtype: float64
# Moda del Óxido Nïtrico de la estacion 1: 0    1.0
# Name: NO, dtype: float64
# Moda del Dióxido de Nitrógeno de la estacion 1: 0    8.0
# Name: NO2, dtype: float64
# Moda del Monóxido de carbono de la estacion 1: Series([], Name: CO, dtype: float64)
# Moda de partículas sólidas en el aire de hasta 10 micras de la estacion 1: 0    27.0
# Name: PM10, dtype: float64
# Moda del Ozono de la estacion 1: 0    6.0
# Name: O3, dtype: float64
# Moda de partículas sólidas en el aire de hasta 2,5 micras de la estacion 1: 0    8.0
# Name: PM25, dtype: float64

# %%
mediana_so2 = dfestacion1["SO2"].median()
print("Mediana del Dióxido de Azufre de la estacion 1:", round(mediana_so2, 2))

mediana_no = dfestacion1["NO"].median()
print("Mediana del Óxido Nítrico de la estacion 1:", round(mediana_no, 2))

mediana_no2 = dfestacion1["NO2"].median()
print("Mediana del Dióxido de Nitrógeno de la estacion 1:", round(mediana_no2, 2))

mediana_co = dfestacion1["CO"].median()
print("Mediana del Monóxido de carbono de la estacion 1:", round(mediana_co, 2))

mediana_pm10 = dfestacion1["PM10"].median()
print("Mediana de partículas sólidas en el aire de hasta 10 micras de la estacion 1:", round(mediana_pm10, 2))

mediana_o3 = dfestacion1["O3"].median()
print("Mediana del Ozono de la estacion 1:", round(mediana_o3, 2))

mediana_pm25 = dfestacion1["PM25"].median()
print("Mediana de partículas sólidas en el aire de hasta 2,5 micras de la estacion 1:", round(mediana_pm25, 2))
# Out:
# Mediana del Dióxido de Azufre de la estacion 1: 2.0
# Mediana del Óxido Nïtrico de la estacion 1: 3.0
# Mediana del Dióxido de Nitrógeno de la estacion 1: 17.0
# Mediana del Monóxido de carbono de la estacion 1: nan
# Mediana de partículas sólidas en el aire de hasta 10 micras de la estacion 1: 28.0
# Mediana del Ozono de la estacion 1: 54.0
# Mediana de partículas sólidas en el aire de hasta 2,5 micras de la estacion 1: 10.0
# c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\lib\nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)

# %%
df['Fecha'] = pd.to_datetime(df['Fecha'])

# %%
maximo_so2 = dfestacion1["SO2"].max()
fecha_max_so2 = df.loc[df["SO2"].idxmax(), "Fecha"]
print(f"Valor máximo del Dióxido de Azufre {round(maximo_so2, 2)} de la estacion 1 en: {fecha_max_so2}")

maximo_no = dfestacion1["NO"].max()
fecha_max_no = df.loc[df["NO"].idxmax(), "Fecha"]
print(f"Valor máximo del Óxido Nítrico {round(maximo_no, 2)} de la estacion 1 en: {fecha_max_no}")

maximo_no2 = dfestacion1["NO2"].max()
fecha_max_no2 = df.loc[df["NO2"].idxmax(), "Fecha"]
print(f"Valor máximo del Dióxido de Nitrógeno {round(maximo_no2, 2)} de la estacion 1 en: {fecha_max_no2}")

maximo_co = dfestacion1["CO"].max()
fecha_max_co = df.loc[df["CO"].idxmax(), "Fecha"]
print(f"Valor máximo del Monóxido de Carbono {round(maximo_co, 2)} de la estacion 1 en: {fecha_max_co}")

maximo_pm10 = dfestacion1["PM10"].max()
fecha_max_pm10 = df.loc[df["PM10"].idxmax(), "Fecha"]
print(f"Valor máximo de partículas sólidas en el aire de hasta 10 micras {round(maximo_pm10, 2)} de la estacion 1 en: {fecha_max_pm10}")

maximo_o3 = dfestacion1["O3"].max()
fecha_max_o3 = df.loc[df["O3"].idxmax(), "Fecha"]
print(f"Valor máximo del Ozono {round(maximo_o3, 2)} de la estacion 1 en: {fecha_max_o3}")

maximo_pm25 = dfestacion1["PM25"].max()
fecha_max_pm25 = df.loc[df["PM25"].idxmax(), "Fecha"]
print(f"Valor máximo de partículas sólidas en el aire de hasta 2,5 micras{round(maximo_pm25, 2)} de la estacion 1 en: {fecha_max_pm25}")
# Out:
# Valor máximo del Dióxido de Azufre 78.0 de la estacion 1 en: 2022-06-25 00:00:00
# Valor máximo del Óxido Nítrico 213.0 de la estacion 1 en: 2022-12-30 00:00:00
# Valor máximo del Dióxido de Nitrógeno 96.0 de la estacion 1 en: 2022-12-10 00:00:00
# Valor máximo del Monóxido de Carbono nan de la estacion 1 en: 2022-11-13 00:00:00
# Valor máximo de partículas sólidas en el aire de hasta 10 micras de la estacion 143.0 de la estacion 1 en: 2022-02-10 00:00:00
# Valor máximo del Ozono 149.0 de la estacion 1 en: 2022-07-17 00:00:00
# Valor máximo de partículas sólidas en el aire de hasta 2,5 micras77.0 de la estacion 1 en: 2022-02-03 00:00:00

# %%
minimo_so2 = dfestacion1["SO2"].min()
print("Valor mínimo del Dióxido de Azufre de la estacion 1:", round(minimo_so2, 2))

minimo_no = dfestacion1["NO"].min()
print("Valor mínimo del Óxido Nítrico de la estacion 1:", round(minimo_no, 2))

minimo_no2 = dfestacion1["NO2"].min()
print("Valor mínimo del Dióxido de Nitrógeno de la estacion 1:", round(minimo_no2, 2))

minimo_co = dfestacion1["CO"].min()
print("Valor mínimo del Monóxido de carbono de la estacion 1:", round(minimo_co, 2))

minimo_pm10 = dfestacion1["PM10"].min()
print("Valor mínimo de partículas sólidas en el aire de hasta 10 micras de la estacion 1:", round(minimo_pm10, 2))

minimo_o3 = dfestacion1["O3"].min()
print("Valor mínimo del Ozono de la estacion 1:", round(minimo_o3, 2))

minimo_pm25 = dfestacion1["PM25"].min()
print("Valor mínimo de partículas sólidas en el aire de hasta 2,5 micras de la estacion 1:", round(minimo_pm25, 2))
# Out:
# Valor mínimo del Dióxido de Azufre de la estacion 1: 1.0
# Valor mínimo del Óxido Nïtrico de la estacion 1: 1.0
# Valor mínimo del Dióxido de Nitrógeno de la estacion 1: 1.0
# Valor mínimo del Monóxido de carbono de la estacion 1: nan
# Valor mínimo de partículas sólidas en el aire de hasta 10 micras de la estacion 1: 5.0
# Valor mínimo del Ozono de la estacion 1: 2.0
# Valor mínimo de partículas sólidas en el aire de hasta 2,5 micras de la estacion 1: 1.0

# %%
desviacion_so2 = dfestacion1["SO2"].std()
print("Desviación del Dióxido de Azufre de la estacion 1:", round(desviacion_so2, 2))

desviacion_no = dfestacion1["NO"].std()
print("Desviación del Óxido Nítrico de la estacion 1:", round(desviacion_no, 2))

desviacion_no2 = dfestacion1["NO2"].std()
print("Desviación del Dióxido de Nitrógeno de la estacion 1:", round(desviacion_no2, 2))

desviacion_co = dfestacion1["CO"].std()
print("Desviación del Monóxido de carbono de la estacion 1:", round(desviacion_co, 2))

desviacion_pm10 = dfestacion1["PM10"].std()
print("Desviación de partículas sólidas en el aire de hasta 10 micras de la estacion 1:", round(desviacion_pm10, 2))

desviacion_o3 = dfestacion1["O3"].std()
print("Desviación del Ozono de la estacion 1:", round(desviacion_o3, 2))

desviacion_pm25 = dfestacion1["PM25"].std()
print("Desviación de partículas sólidas en el aire de hasta 2,5 micras de la estacion 1:", round(desviacion_pm25, 2))
# Out:
# Desviación del Dióxido de Azufre de la estacion 1: 2.26
# Desviación del Óxido Nïtrico de la estacion 1: 19.65
# Desviación del Dióxido de Nitrógeno de la estacion 1: 15.42
# Desviación del Monóxido de carbono de la estacion 1: nan
# Desviación de partículas sólidas en el aire de hasta 10 micras de la estacion 1: 13.93
# Desviación del Ozono de la estacion 1: 27.95
# Desviación de partículas sólidas en el aire de hasta 2,5 micras de la estacion 1: 7.95

# %%
varianza_so2 = dfestacion1["SO2"].var()
print("Varianza del Dióxido de Azufre de la estacion 1:", round(varianza_so2, 2))

varianza_no = dfestacion1["NO"].var()
print("Varianza del Óxido Nítrico de la estacion 1:", round(varianza_no, 2))

varianza_no2 = dfestacion1["NO2"].var()
print("Varianza del Dióxido de Nitrógeno de la estacion 1:", round(varianza_no2, 2))

varianza_co = dfestacion1["CO"].var()
print("Varianza del Monóxido de carbono de la estacion 1:", round(varianza_co, 2))

varianza_pm10 = dfestacion1["PM10"].var()
print("Varianza de partículas sólidas en el aire de hasta 10 micras de la estacion 1:", round(varianza_pm10, 2))

varianza_o3 = dfestacion1["O3"].var()
print("Varianza del Ozono de la estacion 1:", round(varianza_o3, 2))

varianza_pm25 = dfestacion1["PM25"].var()
print("Varianza de partículas sólidas en el aire de hasta 2,5 micras de la estacion 1:", round(varianza_pm25, 2))
# Out:
# Varianza del Dióxido de Azufre de la estacion 1: 5.1
# Varianza del Óxido Nïtrico de la estacion 1: 386.08
# Varianza del Dióxido de Nitrógeno de la estacion 1: 237.91
# Varianza del Monóxido de carbono de la estacion 1: nan
# Varianza de partículas sólidas en el aire de hasta 10 micras de la estacion 1: 193.92
# Varianza del Ozono de la estacion 1: 781.27
# Varianza de partículas sólidas en el aire de hasta 2,5 micras de la estacion 1: 63.27

# %%
#AGENTE CONTAMINANTE DEL AIRE

plt.figure(figsize=(10, 6))
sns.histplot(dfestacion1["NO2"], kde=True, bins=20)

plt.title("Histograma y Densidad de Probabilidad para el Nivel de Dióxido de Nitrógeno")
plt.xlabel("Nivel de NO2")
plt.ylabel("Frecuencia")

plt.show()

# %%
variables = ['SO2', 'NO2', 'CO', 'PM10', 'O3', 'PM25']

fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(15, 8))
fig.suptitle('Histogramas de Calidad del Aire en Gijón en la estación 1 (2022)')

dfestacion1[variables].hist(ax=axes, bins=10, color='blue', edgecolor='black')

plt.show()

# %%
dfest1 = dfestacion1.drop(["Estación", "Título","Fecha","latitud", "longitud", "Periodo"], axis= 1)

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data=dfest1[variables])
plt.title('Diagrama de Caja para Variables Seleccionadas')
plt.show()

# %%
#ANÁLISIS BIVARIANTE

dfestacion1.describe()
# Out:
#        Estación      latitud     longitud      Periodo          SO2  \
# count    8760.0  8760.000000  8760.000000  8760.000000  8643.000000
# mean        1.0    43.529806    -5.673428    12.500000     2.297582
# std         0.0     0.000000     0.000000     6.922582     2.257304
# min         1.0    43.529806    -5.673428     1.000000     1.000000
# 25%         1.0    43.529806    -5.673428     6.750000     1.000000
# 50%         1.0    43.529806    -5.673428    12.500000     2.000000
# 75%         1.0    43.529806    -5.673428    18.250000     3.000000
# max         1.0    43.529806    -5.673428    24.000000    78.000000
#
#                 NO          NO2   CO         PM10           O3         PM25
# count  8664.000000  8649.000000  0.0  8656.000000  8638.000000  8638.000000
# mean      9.882156    21.003815  NaN    30.862061    51.801806    12.342903
# std      19.648835    15.424478  NaN    13.925424    27.951277     7.954123
# ...

# %%
sns.jointplot(x=dfest1['PM10'],
              y=dfest1['PM25'],
              color="#4CB391",
             height = 8);

# %%
#ANÁLISIS MULTIVARIANTE

plt.figure(figsize=(10,10))
sns.heatmap(dfest1.corr(),vmin=-1, vmax=1, center=0,
            cmap=sns.diverging_palette(145, 280, s=85, l=25, n=7),
            square=True, linewidths=.5, annot=True);
